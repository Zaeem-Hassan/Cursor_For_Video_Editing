# %%
print("hi")
# Out:
# hi

# %%
import sys
import subprocess

# Ensure pip exists in this kernel, then install notebook deps.
subprocess.check_call([sys.executable, "-m", "ensurepip", "--upgrade"])
subprocess.check_call([
    sys.executable,
    "-m",
    "pip",
    "install",
    "ffmpeg-python",
    "Pillow",
])
# Out:
# 0

# %%
import cv2
import ffmpeg
import numpy as np
import os
from IPython.display import display, Image
from PIL import Image as PILImage

print("✅ OpenCV:", cv2.__version__)
print("✅ All imports successful")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 6
#       4 import os
#       5 from IPython.display import display, Image
# ----> 6 from PIL import Image as PILImage
#       8 print("✅ OpenCV:", cv2.__version__)
#       9 print("✅ All imports successful")
#
# ModuleNotFoundError: No module named 'PIL'

# %%
! pip install  ffmpeg-python
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Zaeem Hassan\AppData\Local\Programs\Python\Python311\Scripts\pip.exe\__main__.py", line 2, in <module>
#   File "C:\Users\Zaeem Hassan\AppData\Roaming\uv\python\cpython-3.10-windows-x86_64-none\Lib\re.py", line 125, in <module>
#     import sre_compile
#   File "C:\Users\Zaeem Hassan\AppData\Roaming\uv\python\cpython-3.10-windows-x86_64-none\Lib\sre_compile.py", line 17, in <module>
#     assert _sre.MAGIC == MAGIC, "SRE module mismatch"
#            ^^^^^^^^^^^^^^^^^^^
# AssertionError: SRE module mismatch
